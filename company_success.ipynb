# %%
# imports

import numpy as np
import pandas as pd
import os

from pandas import DataFrame

import plotly.plotly as py
import plotly.graph_objs as go
import plotly.offline as offline
import plotly.tools as tls
import matplotlib
import matplotlib.pyplot as plt
import pylab
from mpl_toolkits.mplot3d import Axes3D
import random
import seaborn as sns

# %matplotlib inline
from sklearn.metrics import plot_roc_curve
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.utils import resample
#import tensorflow as tf
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#Loading companies data into data frame

companies = pd.read_csv('companies.csv')
companies.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %%
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %%
companies.dtypes
# Out:
# permalink            object
# name                 object
# homepage_url         object
# category_list        object
# funding_total_usd    object
# status               object
# country_code         object
# state_code           object
# region               object
# city                 object
# funding_rounds        int64
# founded_at           object
# first_funding_at     object
# last_funding_at      object
# success               int64
# dtype: object

# %%
# Drop null records
companies = companies.replace('?', np.nan)
companies = companies.replace('-', np.nan)
companies = companies.dropna()

# %%
# check the count of null records
companies[companies.isnull().any(axis=1)].count()
# Out:
# permalink            0
# name                 0
# homepage_url         0
# category_list        0
# funding_total_usd    0
# status               0
# country_code         0
# state_code           0
# region               0
# city                 0
# funding_rounds       0
# founded_at           0
# first_funding_at     0
# last_funding_at      0
# success              0
# dtype: int64

# %%
# Drop duplicates
companies.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#                                  permalink                    name  \
# 1                   /organization/-qounter                :Qounter
# 3                    /organization/0-6-com                 0-6.com
# 6      /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                     /organization/0xdata                  H2O.ai
# 8                          /organization/1                One Inc.
# ...                                    ...                     ...
# 66358       /organization/zyraz-technology        Zyraz Technology
# 66361             /organization/zytoprotec              Zytoprotec
# 66362                  /organization/zzish                   Zzish
# 66364            /organization/zzzzapp-com   Zzzzapp Wireless ltd.
# 66366                /organization/Ôasys-2                   Ôasys
#
#                     homepage_url  \
# 1         http://www.qounter.com
# 3             http://www.0-6.com
# 6           http://ondinebio.com
# 7                 http://h2o.ai/
# 8             http://whatis1.com
# ...                          ...
# 66358       http://www.zyraz.com
# 66361  http://www.zytoprotec.com
# 66362       http://www.zzish.com
# 66364     http://www.zzzzapp.com
# 66366       http://www.oasys.io/
#
#                                            category_list  funding_total_usd  \
# 1      Application Platforms|Real Time|Social Network...           700000.0
# 3                                            Curated Web          2000000.0
# 6                                          Biotechnology           762851.0
# 7                                              Analytics         33600000.0
# 8                                                 Mobile          1150050.0
# ...                                                  ...                ...
# 66358                                      Biotechnology         15419877.0
# 66361                                      Biotechnology          2686600.0
# 66362  Analytics|Android|Developer APIs|Education|Gam...          1120000.0
# 66364        Advertising|Mobile|Web Development|Wireless           114304.0
# 66366  Consumer Electronics|Internet of Things|Teleco...            18192.0
#
#           status country_code state_code       region                   city  \
# 1      operating          USA         DE   DE - Other          Delaware City
# 3      operating          CHN         22      Beijing                Beijing
# 6      operating          CAN         BC    Vancouver              Vancouver
# 7      operating          USA         CA  SF Bay Area          Mountain View
# 8      operating          USA         CA  SF Bay Area          San Francisco
# ...          ...          ...        ...          ...                    ...
# 66358     closed          MYS         14  MYS - Other  Damansara New Village
# 66361  operating          AUT          3       Vienna     Gerasdorf Bei Wien
# 66362  operating          GBR         H9       London                 London
# 66364  operating          HRV         15        Split                  Split
# 66366  operating          USA         CA  SF Bay Area          San Francisco
#
#        funding_rounds  founded_at first_funding_at last_funding_at  success
# 1                   2  2014-09-04       2014-03-01      2014-10-14        0
# 3                   1  2007-01-01       2008-03-19      2008-03-19        0
# 6                   2  1997-01-01       2009-09-11      2009-12-21        0
# 7                   4  2011-01-01       2013-01-03      2015-11-09        0
# 8                   3  2011-08-01       2011-07-20      2014-02-05        0
# ...               ...         ...              ...             ...      ...
# 66358               4  1994-01-01       2008-01-01      2013-02-15        0
# 66361               1  2007-01-01       2013-01-29      2013-01-29        0
# 66362               3  2014-01-28       2014-03-24      2015-02-25        0
# 66364               4  2012-05-13       2011-11-01      2014-03-01        0
# 66366               1  2014-01-01       2015-01-01      2015-01-01        0
#
# [36552 rows x 15 columns]

# %%
companies["funding_total_usd"] = companies["funding_total_usd"].astype(float)

# %%
companies.describe()
# Out:
#        funding_total_usd  funding_rounds       success
# count       3.655200e+04    36552.000000  36552.000000
# mean        2.022148e+07        2.088504      0.123276
# std         2.095806e+08        1.603963      0.328759
# min         1.000000e+00        1.000000      0.000000
# 25%         3.950000e+05        1.000000      0.000000
# 50%         2.025000e+06        2.000000      0.000000
# 75%         1.080000e+07        3.000000      0.000000
# max         3.007950e+10       19.000000      1.000000

# %%
# create feature success with 0 or 1. 1 (successful) is in case of IPO or acquired

companies['success'] = companies['status']
companies.loc[companies['status'] == 'ipo', 'success'] = 1
companies.loc[companies['status'] == 'acquired', 'success'] = 1
companies.loc[companies['status'] == 'operating', 'success'] = 0
companies.loc[companies['status'] == 'closed', 'success'] = 0

# %%
# funding duration - difference between first and last funding

first = pd.to_datetime(companies.first_funding_at, errors='coerce')
first = pd.to_timedelta(first).dt.days
last = pd.to_datetime(companies.last_funding_at, errors='coerce')
last = pd.to_timedelta(last).dt.days

companies['funding_duration'] = last - first
# Out:
# c:\users\jahmad\appdata\local\programs\python\python37-32\lib\site-packages\pandas\util\_decorators.py:208: FutureWarning:
#
# Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version

# %%
#Drop unnecessary features
companies.drop(['permalink','homepage_url','status','country_code','state_code','region','city','founded_at','first_funding_at','last_funding_at'], 'columns', inplace=True)

# %%
companies.head()
# Out:
#                      name                                      category_list  \
# 1                :Qounter  Application Platforms|Real Time|Social Network...
# 3                 0-6.com                                        Curated Web
# 6  Ondine Biomedical Inc.                                      Biotechnology
# 7                  H2O.ai                                          Analytics
# 8                One Inc.                                             Mobile
#
#    funding_total_usd  funding_rounds  success  funding_duration
# 1           700000.0               2        0             227.0
# 3          2000000.0               1        0               0.0
# 6           762851.0               2        0             101.0
# 7         33600000.0               4        0            1040.0
# 8          1150050.0               3        0             931.0

# %%
companies.hist(figsize=(8,8))
plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x23BCB1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x23BE6E90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x22294D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x222B4E70>]],
#       dtype=object)

# %%
companies.success.value_counts()
# Out:
# 0    32046
# 1     4506
# Name: success, dtype: int64

# %%
# fix the imbalanced class issue by upsampling

success0 = companies[companies.success==0]
success1 = companies[companies.success==1]

# upsample minority
success1_upsampled = resample(success1,
replace=True, # sample with replacement
n_samples=len(success0), # match number in majority class
random_state=27)

#combine majority and upsampled minority
upsampled = pd.concat([success0, success1_upsampled])
# check new class counts
upsampled.success.value_counts()
# Out:
# 1    32046
# 0    32046
# Name: success, dtype: int64

# %%
upsampled.describe()
# Out:
#        funding_total_usd  funding_rounds       success  funding_duration
# count       6.409200e+04    64092.000000  64092.000000      64090.000000
# mean        3.614577e+07        2.333973      0.500000        656.308051
# std         3.690257e+08        1.784729      0.500004        927.523778
# min         1.000000e+00        1.000000      0.000000          0.000000
# 25%         1.000000e+06        1.000000      0.000000          0.000000
# 50%         5.117500e+06        2.000000      0.500000        257.000000
# 75%         2.280000e+07        3.000000      1.000000       1016.000000
# max         3.007950e+10       19.000000      1.000000      33628.000000

# %%
upsampled.hist(figsize=(8,8))
plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x23BCBBD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x224F5610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x2250F6D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2030F7B0>]],
#       dtype=object)

# %%
#split dataset in features and target variable
feature_cols = ['funding_total_usd','funding_rounds','funding_duration']
X = upsampled[feature_cols] # Features
y = upsampled.success # Target variable

# %%
#Heatmap for correlation between the features

correlation = sns.heatmap(X.corr(), annot=True)
visualize = correlation.get_figure()
